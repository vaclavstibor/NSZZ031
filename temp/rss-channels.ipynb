# %%
import feedparser as fp
import pandas as pd
import json
import newspaper
import dateutil
from datetime import *
import nltk
from IPython.display import display
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# nltk.download('punkt')

pd.options.display.max_columns = 20    #Changes the number of columns diplayed (default is 20)
pd.options.display.max_rows = 60       #Changes the number of rows diplayed (default is 60)
pd.options.display.max_colwidth = 500   #Changes the number of characters in a cell (default is 50)

# %%
def load_sources(file):
    # Function that loads in the sources from the JSON database
    try:
        with open(file) as data:
            sources = json.load(data)
        print(f'INFO: Using custom "{file}" as source file.')
        return sources
    except:
        raise Exception(f'Error in "load_sources()"')

sources = "sources.json"
data = load_sources(sources)
# Out:
# INFO: Using custom "sources.json" as source file.

# %%
def analyze_sentiment(text):
    analyzer = SentimentIntensityAnalyzer()
    sentiment = analyzer.polarity_scores(text)
    return sentiment['compound']

# %%
for source, content in data.items():
    urls = content['rss']
    for url in urls:
        print(url)
        feed = fp.parse(url)
        display(feed)
# Out:
# https://rss.nytimes.com/services/xml/rss/nyt/Business.xml
# {'bozo': False,
#  'entries': [{'title': 'In a Shaky Oil Market, OPEC Has Bitter Decisions to Make',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'In a Shaky Oil Market, OPEC Has Bitter Decisions to Make'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/11/29/business/energy-environment/opec-oil-prices.html'},
#     {'href': 'https://www.nytimes.com/2023/11/29/business/energy-environment/opec-oil-prices.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/11/29/business/energy-environment/opec-oil-prices.html',
#    'id': 'https://www.nytimes.com/2023/11/29/business/energy-environment/opec-oil-prices.html',
#    'guidislink': False,
#    'summary': 'Anticipating a drop in demand for 2024, major producers, led by Saudi Arabia, are trying to reduce supply.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'Anticipating a drop in demand for 2024, major producers, led by Saudi Arabia, are trying to reduce supply.'},
#    'authors': [{'name': 'Stanley Reed'}],
#    'author': 'Stanley Reed',
#    'author_detail': {'name': 'Stanley Reed'},
#    'published': 'Wed, 29 Nov 2023 14:43:49 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=11, tm_mday=29, tm_hour=14, tm_min=43, tm_sec=49, tm_wday=2, tm_yday=333, tm_isdst=0),
#    'tags': [{'term': 'Oil (Petroleum) and Gasoline',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Production',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Israel-Gaza War (2023- )',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Prices (Fares, Fees and Rates)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Organization of the Petroleum Exporting Countries',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Saudi Aramco',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Saudi Arabia',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None}],
#    'media_content': [{'height': '1799',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/11/28/multimedia/00opec-supplies-qpcj/00opec-supplies-qpcj-mediumSquareAt3X.jpg',
#      'width': '1800'}],
#    'media_credit': [{'content': 'Alexey Malgavko/Reuters'}],
#    'credit': 'Alexey Malgavko/Reuters',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#      'value': 'An oil refinery in Omsk, Russia, which is among the countries cutting production.'}]},
#   {'title': 'Citi Executive Sues the Bank Over Sexual Harassment',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'Citi Executive Sues the Bank Over Sexual Harassment'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/11/29/business/citi-sex-harassment-lawsuit.html'},
#     {'href': 'https://www.nytimes.com/2023/11/29/business/citi-sex-harassment-lawsuit.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/11/29/business/citi-sex-harassment-lawsuit.html',
#    'id': 'https://www.nytimes.com/2023/11/29/business/citi-sex-harassment-lawsuit.html',
#    'guidislink': False,
#    'summary': 'Ardith Lindsey, a managing director, is accusing the bank of tolerating a culture in which managers sexually harassed her.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'Ardith Lindsey, a managing director, is accusing the bank of tolerating a culture in which managers sexually harassed her.'},
#    'authors': [{'name': 'Emily Flitter'}],
#    'author': 'Emily Flitter',
#    'author_detail': {'name': 'Emily Flitter'},
#    'published': 'Wed, 29 Nov 2023 14:33:05 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=11, tm_mday=29, tm_hour=14, tm_min=33, tm_sec=5, tm_wday=2, tm_yday=333, tm_isdst=0),
#    'tags': [{'term': 'Workplace Hazards and Violations',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Sexual Harassment',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Discrimination',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Banking and Financial Institutions',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': '#MeToo Movement',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Threats and Threatening Messages',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Workplace Environment',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Citigroup Inc',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None}],
#    'media_content': [{'height': '1799',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/11/14/multimedia/00citi-women-01-pgbv/00citi-women-01-pgbv-mediumSquareAt3X.jpg',
#      'width': '1800'}],
#    'media_credit': [{'content': 'Maansi Srivastava/The New York Times'}],
#    'credit': 'Maansi Srivastava/The New York Times',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#      'value': 'Ardith Lindsey alleged in a lawsuit that she had suffered sexual harassment at Citigroup.'}]},
#   {'title': 'G.M. to Cut Spending on Cruise Self-Driving Unit',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'G.M. to Cut Spending on Cruise Self-Driving Unit'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/11/29/technology/cruise-general-motors.html'},
#     {'href': 'https://www.nytimes.com/2023/11/29/technology/cruise-general-motors.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/11/29/technology/cruise-general-motors.html',
#    'id': 'https://www.nytimes.com/2023/11/29/technology/cruise-general-motors.html',
#    'guidislink': False,
#    'summary': 'General Motors will “substantially lower spending” on autonomous vehicle efforts in 2024 after accidents with its self-driving taxis in San Francisco.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'General Motors will “substantially lower spending” on autonomous vehicle efforts in 2024 after accidents with its self-driving taxis in San Francisco.'},
#    'authors': [{'name': 'Neal E. Boudette and Yiwen Lu'}],
#    'author': 'Neal E. Boudette and Yiwen Lu',
#    'author_detail': {'name': 'Neal E. Boudette and Yiwen Lu'},
#    'published': 'Wed, 29 Nov 2023 18:54:46 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=11, tm_mday=29, tm_hour=18, tm_min=54, tm_sec=46, tm_wday=2, tm_yday=333, tm_isdst=0),
#    'tags': [{'term': 'Driverless and Semiautonomous Vehicles',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Automobiles',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Traffic Accidents and Safety',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Computers and the Internet',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Cruise LLC',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'General Motors',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Barra, Mary T',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Vogt, Kyle',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None}],
#    'media_content': [{'height': '1800',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/11/30/multimedia/29bizsky-gm-cruise-print/29gm-cruise-hcjk-mediumSquareAt3X.jpg',
#      'width': '1800'}],
#    'media_credit': [{'content': 'Jim Wilson/The New York Times'}],
#    'credit': 'Jim Wilson/The New York Times',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#      'value': 'A fleet of Cruise vehicles in San Francisco. California regulators suspended Cruise’s operating license last month.'}]},
#   {'title': 'DealBook Summit: Vice President Kamala Harris Interviewed at New York Times Forum',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'DealBook Summit: Vice President Kamala Harris Interviewed at New York Times Forum'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/live/2023/11/29/business/dealbook-summit-news'},
#     {'href': 'https://www.nytimes.com/live/2023/11/29/business/dealbook-summit-news',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/live/2023/11/29/business/dealbook-summit-news',
#    'id': 'https://www.nytimes.com/live/2023/11/29/business/dealbook-summit-news',
#    'guidislink': False,
#    'summary': 'Ms. Harris is among the headliners of the 2023 DealBook Summit, along with President Isaac Herzog of Israel, President Tsai Ing-wen of Taiwan and Elon Musk. Follow along and watch select interviews.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'Ms. Harris is among the headliners of the 2023 DealBook Summit, along with President Isaac Herzog of Israel, President Tsai Ing-wen of Taiwan and Elon Musk. Follow along and watch select interviews.'},
#    'authors': [{'name': 'The New York Times'}],
#    'author': 'The New York Times',
#    'author_detail': {'name': 'The New York Times'},
#    'published': 'Wed, 29 Nov 2023 19:14:53 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=11, tm_mday=29, tm_hour=19, tm_min=14, tm_sec=53, tm_wday=2, tm_yday=333, tm_isdst=0),
#    'media_content': [{'height': '1800',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/11/29/multimedia/29dealbook-summit-header-12p-jwql/29dealbook-summit-header-12p-jwql-mediumSquareAt3X.jpg',
#      'width': '1800'}],
#    'media_credit': [{'content': 'Haiyun Jiang for The New York Times'}],
#    'credit': 'Haiyun Jiang for The New York Times',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#      'value': 'Isaac Herzog, the president of Israel, spoke with Andrew Ross Sorkin at the DealBook Summit held at Jazz at Lincoln Center in Manhattan on Wednesday.'}]},
#   {'title': 'Corporate America Has Dodged the Damage of High Rates. For Now.',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'Corporate America Has Dodged the Damage of High Rates. For Now.'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/11/28/business/economy/corporate-interest-rates.html'},
#     {'href': 'https://www.nytimes.com/2023/11/28/business/economy/corporate-interest-rates.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/11/28/business/economy/corporate-interest-rates.html',
#    'id': 'https://www.nytimes.com/2023/11/28/business/economy/corporate-interest-rates.html',
#    'guidislink': False,
#    'summary': 'Small businesses and risky borrowers face rising costs from the Federal Reserve’s moves, but the biggest companies have avoided taking a hit.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'Small businesses and risky borrowers face rising costs from the Federal Reserve’s moves, but the biggest companies have avoided taking a hit.'},
#    'authors': [{'name': 'Talmon Joseph Smith and Joe Rennison'}],
#    'author': 'Talmon Joseph Smith and Joe Rennison',
#    'author_detail': {'name': 'Talmon Joseph Smith and Joe Rennison'},
#    'published': 'Tue, 28 Nov 2023 20:46:11 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=11, tm_mday=28, tm_hour=20, tm_min=46, tm_sec=11, tm_wday=1, tm_yday=332, tm_isdst=0),
#    'tags': [{'term': 'Banking and Financial Institutions',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Small Business',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Private Equity',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Interest Rates',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Corporations',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Inflation (Economics)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Junk Bonds',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'United States Economy',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Credit and Debt',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Credit Ratings and Credit Rating Agencies',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Federal Reserve System',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None}],
#    'media_content': [{'height': '1000',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/11/28/multimedia/corportate-debt-promo-index/corportate-debt-promo-index-mediumSquareAt3X.png',
#      'width': '1000'}]},
#   {'title': 'Gold Bars and Tokyo Apartments: How Money Is Flowing Out of China.',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'Gold Bars and Tokyo Apartments: How Money Is Flowing Out of China.'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/11/28/business/china-money-overseas.html'},
#     {'href': 'https://www.nytimes.com/2023/11/28/business/china-money-overseas.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/11/28/business/china-money-overseas.html',
#    'id': 'https://www.nytimes.com/2023/11/28/business/china-money-overseas.html',
#    'guidislink': False,
#    'summary': 'Chinese families are sending money overseas, a sign of worry about the country’s economic and political future. But a cheaper currency is also helping exports.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'Chinese families are sending money overseas, a sign of worry about the country’s economic and political future. But a cheaper currency is also helping exports.'},
#    'authors': [{'name': 'Keith Bradsher and Joy Dong'}],
#    'author': 'Keith Bradsher and Joy Dong',
#    'author_detail': {'name': 'Keith Bradsher and Joy Dong'},
#    'published': 'Tue, 28 Nov 2023 14:31:51 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=11, tm_mday=28, tm_hour=14, tm_min=31, tm_sec=51, tm_wday=1, tm_yday=332, tm_isdst=0),
#    'tags': [{'term': 'Economic Conditions and Trends',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Foreign Investments',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Banking and Financial Institutions',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Gold',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Currency',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'China',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Hong Kong',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Savings',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Real Estate and Housing (Residential)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None}],
#    'media_content': [{'height': '1800',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/11/28/multimedia/28china-money-flight-01-gvth/28china-money-flight-01-gvth-mediumSquareAt3X.jpg',
#      'width': '1800'}],
#    'media_credit': [{'content': 'Billy H.C. Kwok para The New York Times'}],
#    'credit': 'Billy H.C. Kwok para The New York Times',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#      'value': 'Turistas chinos comprando lingotes y accesorios de oro en LukFook, una joyería de Hong Kong, el domingo.'}]},
#   {'title': 'Even Most Biden Voters Don’t See a Thriving Economy',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'Even Most Biden Voters Don’t See a Thriving Economy'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/11/28/business/economy/democrats-biden-economy.html'},
#     {'href': 'https://www.nytimes.com/2023/11/28/business/economy/democrats-biden-economy.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/11/28/business/economy/democrats-biden-economy.html',
#    'id': 'https://www.nytimes.com/2023/11/28/business/economy/democrats-biden-economy.html',
#    'guidislink': False,
#    'summary': 'A majority of those who backed President Biden in 2020 say today’s economy is fair or poor, ordinarily a bad omen for incumbents seeking re-election.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'A majority of those who backed President Biden in 2020 say today’s economy is fair or poor, ordinarily a bad omen for incumbents seeking re-election.'},
#    'authors': [{'name': 'Lydia DePillis'}],
#    'author': 'Lydia DePillis',
#    'author_detail': {'name': 'Lydia DePillis'},
#    'published': 'Tue, 28 Nov 2023 23:38:05 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=11, tm_mday=28, tm_hour=23, tm_min=38, tm_sec=5, tm_wday=1, tm_yday=332, tm_isdst=0),
#    'tags': [{'term': 'Presidential Election of 2024',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Polls and Public Opinion',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'United States Economy',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Biden, Joseph R Jr',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Democratic Party',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Inflation (Economics)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'United States Politics and Government',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'New York Times/Siena College Poll',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Trump, Donald J',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'audio-neutral-informative',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None}],
#    'media_content': [{'height': '1801',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/11/22/multimedia/00biden-econ-01-pcwh/00biden-econ-01-pcwh-mediumSquareAt3X.jpg',
#      'width': '1800'}],
#    'media_credit': [{'content': 'Audra Melton for The New York Times'}],
#    'credit': 'Audra Melton for The New York Times',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#      'value': 'Lawson Millwood and Mackenzie Kiser, who managed to buy a house this year, worried that affordability would only worsen if they waited because of rising interest rates and prices.'}]},
#   {'title': 'Fed Officials Hint That Rate Increases Are Over, and Investors Celebrate',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'Fed Officials Hint That Rate Increases Are Over, and Investors Celebrate'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/11/28/business/economy/federal-reserve-interest-rates.html'},
#     {'href': 'https://www.nytimes.com/2023/11/28/business/economy/federal-reserve-interest-rates.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/11/28/business/economy/federal-reserve-interest-rates.html',
#    'id': 'https://www.nytimes.com/2023/11/28/business/economy/federal-reserve-interest-rates.html',
#    'guidislink': False,
#    'summary': 'Stocks and bonds were buoyed after even inflation-focused Federal Reserve officials suggested that rates may stay steady.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'Stocks and bonds were buoyed after even inflation-focused Federal Reserve officials suggested that rates may stay steady.'},
#    'authors': [{'name': 'Jeanna Smialek and Joe Rennison'}],
#    'author': 'Jeanna Smialek and Joe Rennison',
#    'author_detail': {'name': 'Jeanna Smialek and Joe Rennison'},
#    'published': 'Tue, 28 Nov 2023 21:08:55 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=11, tm_mday=28, tm_hour=21, tm_min=8, tm_sec=55, tm_wday=1, tm_yday=332, tm_isdst=0),
#    'tags': [{'term': 'Interest Rates',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Prices (Fares, Fees and Rates)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Inflation (Economics)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Gross Domestic Product',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Bowman, Michelle',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Waller, Christopher (1959- )',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Federal Reserve System',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Stocks and Bonds',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': "Standard & Poor's 500-Stock Index",
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None}],
#    'media_content': [{'height': '1801',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/11/28/multimedia/28dc-Fedmarkets-vpcz/28dc-Fedmarkets-vpcz-mediumSquareAt3X.jpg',
#      'width': '1800'}],
#    'media_credit': [{'content': 'Brendan McDermid/Reuters'}],
#    'credit': 'Brendan McDermid/Reuters',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#      'value': 'The 10-year Treasury yield has fallen drastically over the past month as investors increasingly believe the Federal Reserve will stop raising interest rates.'}]},
#   {'title': 'Amazon Introduces Q, an A.I. Chatbot for Companies',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'Amazon Introduces Q, an A.I. Chatbot for Companies'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/11/28/technology/amazon-ai-chatbot-q.html'},
#     {'href': 'https://www.nytimes.com/2023/11/28/technology/amazon-ai-chatbot-q.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/11/28/technology/amazon-ai-chatbot-q.html',
#    'id': 'https://www.nytimes.com/2023/11/28/technology/amazon-ai-chatbot-q.html',
#    'guidislink': False,
#    'summary': 'Amazon has been racing to shake off the perception that it is lagging in the push to take advantage of artificial intelligence.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'Amazon has been racing to shake off the perception that it is lagging in the push to take advantage of artificial intelligence.'},
#    'authors': [{'name': 'Karen Weise'}],
#    'author': 'Karen Weise',
#    'author_detail': {'name': 'Karen Weise'},
#    'published': 'Tue, 28 Nov 2023 19:10:07 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=11, tm_mday=28, tm_hour=19, tm_min=10, tm_sec=7, tm_wday=1, tm_yday=332, tm_isdst=0),
#    'tags': [{'term': 'Amazon.com Inc',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Artificial Intelligence',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Computers and the Internet',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Cloud Computing',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'ChatGPT',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None}],
#    'media_content': [{'height': '1622',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/11/28/business/28AMAZON-Q-VIDEOCOVER/28AMAZON-Q-VIDEOCOVER-mediumSquareAt3X.png',
#      'width': '1624'}],
#    'media_credit': [{'content': 'Amazon Web Services Inc.'}],
#    'credit': 'Amazon Web Services Inc.',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#      'value': 'Amazon’s new A.I. chatbot “Amazon Q.”'}]},
#   {'title': 'With Charlie Munger’s Death, Berkshire Loses a Custodian of Its Culture',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'With Charlie Munger’s Death, Berkshire Loses a Custodian of Its Culture'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/11/29/business/charlie-munger-berkshire-culture.html'},
#     {'href': 'https://www.nytimes.com/2023/11/29/business/charlie-munger-berkshire-culture.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/11/29/business/charlie-munger-berkshire-culture.html',
#    'id': 'https://www.nytimes.com/2023/11/29/business/charlie-munger-berkshire-culture.html',
#    'guidislink': False,
#    'summary': 'Mr. Munger’s death won’t affect the day-to-day operations of the conglomerate, but shareholders will miss his imprint on the company’s ethos.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'Mr. Munger’s death won’t affect the day-to-day operations of the conglomerate, but shareholders will miss his imprint on the company’s ethos.'},
#    'authors': [{'name': 'Joe Rennison'}],
#    'author': 'Joe Rennison',
#    'author_detail': {'name': 'Joe Rennison'},
#    'published': 'Wed, 29 Nov 2023 19:08:56 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=11, tm_mday=29, tm_hour=19, tm_min=8, tm_sec=56, tm_wday=2, tm_yday=333, tm_isdst=0),
#    'tags': [{'term': 'Stocks and Bonds',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Berkshire Hathaway Inc',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Munger, Charles T',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None}],
#    'media_content': [{'height': '1800',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/11/29/multimedia/MUNGER-01-ptck/MUNGER-ptck-mediumSquareAt3X.jpg',
#      'width': '1800'}],
#    'media_credit': [{'content': 'Nati Harnik/Associated Press'}],
#    'credit': 'Nati Harnik/Associated Press',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#      'value': 'Charlie Munger, who helped build Berkshire into a global investing powerhouse, died at a California hospital on Tuesday morning.'}]},
#   {'title': 'London’s Black Cabs Can Soon Join Uber. But Will They?',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'London’s Black Cabs Can Soon Join Uber. But Will They?'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/11/29/world/europe/uber-black-cab-taxi-london.html'},
#     {'href': 'https://www.nytimes.com/2023/11/29/world/europe/uber-black-cab-taxi-london.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/11/29/world/europe/uber-black-cab-taxi-london.html',
#    'id': 'https://www.nytimes.com/2023/11/29/world/europe/uber-black-cab-taxi-london.html',
#    'guidislink': False,
#    'summary': 'In 2024, passengers are set to have the option to book black cabs through Uber. After longstanding tensions, a union for drivers said they “have no interest.”',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'In 2024, passengers are set to have the option to book black cabs through Uber. After longstanding tensions, a union for drivers said they “have no interest.”'},
#    'authors': [{'name': 'Isabella Kwai'}],
#    'author': 'Isabella Kwai',
#    'author_detail': {'name': 'Isabella Kwai'},
#    'published': 'Wed, 29 Nov 2023 18:59:25 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=11, tm_mday=29, tm_hour=18, tm_min=59, tm_sec=25, tm_wday=2, tm_yday=333, tm_isdst=0),
#    'tags': [{'term': 'Taxicabs and Taxicab Drivers',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Mobile Applications',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Uber Technologies Inc',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Great Britain',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'London (England)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None}],
#    'media_content': [{'height': '1800',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/11/29/multimedia/29xp-black-cab/29xp-black-cab-mediumSquareAt3X.jpg',
#      'width': '1800'}],
#    'media_credit': [{'content': 'Associated Press/EMPPL PA Wire, via Associated Press'}],
#    'credit': 'Associated Press/EMPPL PA Wire, via Associated Press',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#      'value': 'London’s black cabs, also known as hackney carriages, have traversed the capital in one form or another since 1634. When Uber came to the city more than a decade ago, the company rocked the industry.'}]},
#   {'title': 'Don’t Be Afraid of the iPhone’s NameDrop Feature, Experts Say',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'Don’t Be Afraid of the iPhone’s NameDrop Feature, Experts Say'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/11/29/technology/namedrop-apple-iphone-police.html'},
#     {'href': 'https://www.nytimes.com/2023/11/29/technology/namedrop-apple-iphone-police.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/11/29/technology/namedrop-apple-iphone-police.html',
#    'id': 'https://www.nytimes.com/2023/11/29/technology/namedrop-apple-iphone-police.html',
#    'guidislink': False,
#    'summary': 'Police departments have issued warnings about a new Apple setting that lets users exchange contact information by bringing their devices together. Tech experts say the fears are overblown.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'Police departments have issued warnings about a new Apple setting that lets users exchange contact information by bringing their devices together. Tech experts say the fears are overblown.'},
#    'authors': [{'name': 'Jesus Jiménez'}],
#    'author': 'Jesus Jiménez',
#    'author_detail': {'name': 'Jesus Jiménez'},
#    'published': 'Wed, 29 Nov 2023 17:58:22 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=11, tm_mday=29, tm_hour=17, tm_min=58, tm_sec=22, tm_wday=2, tm_yday=333, tm_isdst=0),
#    'tags': [{'term': 'Privacy',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Police',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Software',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'iPhone',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Rumors and Misinformation',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Watches and Clocks',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Wearable Computing',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Wireless Communications',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None}],
#    'media_content': [{'height': '1800',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/11/28/multimedia/28xp-namedrop-qzkg/28xp-namedrop-qzkg-mediumSquareAt3X.jpg',
#      'width': '1800'}],
#    'media_credit': [{'content': 'Patrick T. Fallon/Agence France-Presse — Getty Images'}],
#    'credit': 'Patrick T. Fallon/Agence France-Presse — Getty Images',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#      'value': 'NameDrop is a new feature that allows iPhone users to wirelessly exchange contact information by placing their phones close together.'}]},
#   {'title': 'Here’s the Lineup for the 2023 DealBook Summit, and When to Watch',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'Here’s the Lineup for the 2023 DealBook Summit, and When to Watch'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/11/29/business/dealbook/harris-musk-iger-ai-inflation-antisemitism-streaming-wars.html'},
#     {'href': 'https://www.nytimes.com/2023/11/29/business/dealbook/harris-musk-iger-ai-inflation-antisemitism-streaming-wars.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/11/29/business/dealbook/harris-musk-iger-ai-inflation-antisemitism-streaming-wars.html',
#    'id': 'https://www.nytimes.com/2023/11/29/business/dealbook/harris-musk-iger-ai-inflation-antisemitism-streaming-wars.html',
#    'guidislink': False,
#    'summary': 'Vice President Kamala Harris, President Tsai Ing-wen of Taiwan, and Elon Musk are among those being interviewed Wednesday by The Times’s Andrew Ross Sorkin.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'Vice President Kamala Harris, President Tsai Ing-wen of Taiwan, and Elon Musk are among those being interviewed Wednesday by The Times’s Andrew Ross Sorkin.'},
#    'authors': [{'name': 'The New York Times'}],
#    'author': 'The New York Times',
#    'author_detail': {'name': 'The New York Times'},
#    'published': 'Wed, 29 Nov 2023 15:54:39 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=11, tm_mday=29, tm_hour=15, tm_min=54, tm_sec=39, tm_wday=2, tm_yday=333, tm_isdst=0),
#    'tags': [{'term': 'Dimon, James',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Harris, Kamala D',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Huang, Jen-Hsun',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Iger, Robert A',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'McCarthy, Kevin (1965- )',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Monahan, Jay W (1970- )',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Musk, Elon',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Rhimes, Shonda',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Zaslav, David M',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'DBNY2023', 'scheme': None, 'label': None}],
#    'media_content': [{'height': '1799',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/11/29/multimedia/29dealbook-summit-expect-vqpl/29dealbook-summit-expect-vqpl-mediumSquareAt3X-v2.jpg',
#      'width': '1800'}],
#    'media_credit': [{'content': 'Amir Hamja/The New York Times'}],
#    'credit': 'Amir Hamja/The New York Times',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#      'value': 'Andrew Ross Sorkin making opening remarks at the DealBook Summit at Jazz at Lincoln Center in Manhattan on Wednesday.'}]},
#   {'title': 'Jezebel to Be Resurrected by Paste Magazine',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'Jezebel to Be Resurrected by Paste Magazine'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/11/29/business/media/jezebel-resurrected-paste-magazine.html'},
#     {'href': 'https://www.nytimes.com/2023/11/29/business/media/jezebel-resurrected-paste-magazine.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/11/29/business/media/jezebel-resurrected-paste-magazine.html',
#    'id': 'https://www.nytimes.com/2023/11/29/business/media/jezebel-resurrected-paste-magazine.html',
#    'guidislink': False,
#    'summary': 'The pioneering feminist website is being sold to Paste by G/O Media, which had shut down the site this month.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'The pioneering feminist website is being sold to Paste by G/O Media, which had shut down the site this month.'},
#    'authors': [{'name': 'Katie Robertson'}],
#    'author': 'Katie Robertson',
#    'author_detail': {'name': 'Katie Robertson'},
#    'published': 'Wed, 29 Nov 2023 13:00:09 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=11, tm_mday=29, tm_hour=13, tm_min=0, tm_sec=9, tm_wday=2, tm_yday=333, tm_isdst=0),
#    'tags': [{'term': 'News and News Media',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Mergers, Acquisitions and Divestitures',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': "Women's Rights",
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Jezebel (Blog)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Paste Magazine',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'G/O Media Inc',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Splinter (Web Site)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None}],
#    'media_content': [{'height': '1800',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/11/29/multimedia/29JEZEBEL-Josh-bkfz/29JEZEBEL-Josh-bkfz-mediumSquareAt3X.jpg',
#      'width': '1800'}],
#    'media_credit': [{'content': 'Kendrick Brinson for The New York Times'}],
#    'credit': 'Kendrick Brinson for The New York Times',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#      'value': 'Josh Jackson, the editor in chief and a co-founder of Paste, is acquiring the websites Jezebel and Splinter.'}]},
#   {'title': 'What to Expect at Today’s DealBook Summit',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'What to Expect at Today’s DealBook Summit'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/11/29/business/dealbook/dealbook-summit-harris-musk.html'},
#     {'href': 'https://www.nytimes.com/2023/11/29/business/dealbook/dealbook-summit-harris-musk.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/11/29/business/dealbook/dealbook-summit-harris-musk.html',
#    'id': 'https://www.nytimes.com/2023/11/29/business/dealbook/dealbook-summit-harris-musk.html',
#    'guidislink': False,
#    'summary': 'Vice President Kamala Harris, Elon Musk, Bob Iger, Jamie Dimon and Tsai Ing-wen, the president of Taiwan, are among the big names speaking.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Business.xml',
#     'value': 'Vice President Kamala Harris, Elon Musk, Bob Iger, Jamie Dimon and Tsai Ing-wen, the president of Taiwan, are among the big names speaking.'},
#    'authors': [{'name': 'Andrew Ross Sorkin, Ravi Mattu, Bernhard Warner, Sarah Kessler, Michael J. de la Merced, Lauren Hirsch and Ephrat Livni'}],
#    'author': 'Andrew Ross Sorkin, Ravi Mattu, Bernhard Warner, Sarah Kessler, Michael J. de la Merced, Lauren Hirsch and Ephrat Livni',
#    'author_detail': {'name': 'Andrew Ross Sorkin, Ravi Mattu, Bernhard Warner, Sarah Kessler, Michael J. de la Merced, Lauren Hirsch and Ephrat Livni'},
#    'published': 'Wed, 29 Nov 2023 13:13:17 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=11, tm_mday=29, tm_hour=13, tm_min=13, tm_sec=17, tm_wday=2, tm_yday=333, tm_isdst=0),
#    'tags': [{'term': 'Presidential Election of 2024',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Banking and Financial Institutions',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Artificial Intelligence',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'United States Economy',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Inflation (Economics)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Politics and Government',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Israel-Gaza War (2023- )',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Federal Trade Commission',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'JPMorgan Chase & Company',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'NVIDIA Corporation',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'PGA Tour Inc',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Shondaland (Production Co)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Republican Party',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Space Exploration Technologies Corp',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Tesla Motors Inc',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Walt Disney Company',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Warner Bros Discovery',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Dimon, James',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Iger, Robert A',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Harris, Kamala D',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Huang, Jen-Hsun',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
# ...
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Economy.xml',
#     'value': 'Many longstanding General Motors workers have been voting against the tentative accord, which they feel insufficiently improves retirement benefits.'},
#    'authors': [{'name': 'Neal E. Boudette'}],
#    'author': 'Neal E. Boudette',
#    'author_detail': {'name': 'Neal E. Boudette'},
#    'published': 'Thu, 16 Nov 2023 03:35:30 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=11, tm_mday=16, tm_hour=3, tm_min=35, tm_sec=30, tm_wday=3, tm_yday=320, tm_isdst=0),
#    'tags': [{'term': 'General Motors',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'United Automobile Workers',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Automobiles',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Organized Labor',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Wages and Salaries',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Fain, Shawn',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Ford Motor Co',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Stellantis NV',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Strikes',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Pensions and Retirement Plans',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Employee Fringe Benefits',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Health Insurance and Managed Care',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Factories and Manufacturing',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None}]},
#   {'title': 'U.S. Presses China to Stop Flow of Fentanyl',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Economy.xml',
#     'value': 'U.S. Presses China to Stop Flow of Fentanyl'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/11/15/business/economy/biden-xi-fentanyl.html'},
#     {'href': 'https://www.nytimes.com/2023/11/15/business/economy/biden-xi-fentanyl.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/11/15/business/economy/biden-xi-fentanyl.html',
#    'id': 'https://www.nytimes.com/2023/11/15/business/economy/biden-xi-fentanyl.html',
#    'guidislink': False,
#    'summary': 'President Biden put pressure on Xi Jinping to crack down on the Chinese facilities that make chemical compounds used in potent drugs.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Economy.xml',
#     'value': 'President Biden put pressure on Xi Jinping to crack down on the Chinese facilities that make chemical compounds used in potent drugs.'},
#    'authors': [{'name': 'Ana Swanson and Keith Bradsher'}],
#    'author': 'Ana Swanson and Keith Bradsher',
#    'author_detail': {'name': 'Ana Swanson and Keith Bradsher'},
#    'published': 'Thu, 16 Nov 2023 03:39:21 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=11, tm_mday=16, tm_hour=3, tm_min=39, tm_sec=21, tm_wday=3, tm_yday=320, tm_isdst=0),
#    'tags': [{'term': 'International Relations',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Fentanyl',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'United States Politics and Government',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'United States International Relations',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Chemicals',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Customs and Border Protection (US)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Biden, Joseph R Jr',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Xi Jinping',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'China',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None}],
#    'media_content': [{'height': '1800',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/11/16/multimedia/15DC-FENTANYL-top-cjlw/15DC-FENTANYL-top-cjlw-mediumSquareAt3X.jpg',
#      'width': '1800'}],
#    'media_credit': [{'content': 'Lyndon French for The New York Times'}],
#    'credit': 'Lyndon French for The New York Times',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Economy.xml',
#      'value': 'Examining pollen samples to help determine the origins of fentanyl that enters the United States at a Customs and Border Protection facility in Chicago.'}]},
#   {'title': 'Sharp Drop in Airfares Cheers Inflation-Weary Travelers',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Economy.xml',
#     'value': 'Sharp Drop in Airfares Cheers Inflation-Weary Travelers'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/11/14/business/air-fares-falling-deals.html'},
#     {'href': 'https://www.nytimes.com/2023/11/14/business/air-fares-falling-deals.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/11/14/business/air-fares-falling-deals.html',
#    'id': 'https://www.nytimes.com/2023/11/14/business/air-fares-falling-deals.html',
#    'guidislink': False,
#    'summary': 'Airlines are starting to offer bargain prices, including to popular overseas destinations like Paris, a sign that they are fighting to fill planes.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Economy.xml',
#     'value': 'Airlines are starting to offer bargain prices, including to popular overseas destinations like Paris, a sign that they are fighting to fill planes.'},
#    'authors': [{'name': 'Niraj Chokshi'}],
#    'author': 'Niraj Chokshi',
#    'author_detail': {'name': 'Niraj Chokshi'},
#    'published': 'Tue, 14 Nov 2023 10:03:51 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=11, tm_mday=14, tm_hour=10, tm_min=3, tm_sec=51, tm_wday=1, tm_yday=318, tm_isdst=0),
#    'tags': [{'term': 'Airlines and Airplanes',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Travel and Vacations',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Prices (Fares, Fees and Rates)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Budget Travel',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Coronavirus (2019-nCoV)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'United States',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Europe',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None}],
#    'media_content': [{'height': '1800',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/11/15/multimedia/14Subairfares-print-qgfv/14airfares-qgfv-mediumSquareAt3X.jpg',
#      'width': '1800'}],
#    'media_credit': [{'content': 'Stefani Reynolds for The New York Times'}],
#    'credit': 'Stefani Reynolds for The New York Times',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Economy.xml',
#      'value': 'Airlines lower their fares when they are trying to get more people to book tickets as demand is slowing or they are facing stiffer competition.'}]},
#   {'title': 'Biden’s Pacific Trade Pact Suffers Setback After Criticism From Congress',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Economy.xml',
#     'value': 'Biden’s Pacific Trade Pact Suffers Setback After Criticism From Congress'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2023/11/13/business/economy/indo-pacific-trade-delay.html'},
#     {'href': 'https://www.nytimes.com/2023/11/13/business/economy/indo-pacific-trade-delay.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2023/11/13/business/economy/indo-pacific-trade-delay.html',
#    'id': 'https://www.nytimes.com/2023/11/13/business/economy/indo-pacific-trade-delay.html',
#    'guidislink': False,
#    'summary': 'The administration will no longer try to announce the completion of the trade terms this week, after prominent Democrats objected to some provisions.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Economy.xml',
#     'value': 'The administration will no longer try to announce the completion of the trade terms this week, after prominent Democrats objected to some provisions.'},
#    'authors': [{'name': 'Ana Swanson'}],
#    'author': 'Ana Swanson',
#    'author_detail': {'name': 'Ana Swanson'},
#    'published': 'Tue, 14 Nov 2023 17:42:27 +0000',
#    'published_parsed': time.struct_time(tm_year=2023, tm_mon=11, tm_mday=14, tm_hour=17, tm_min=42, tm_sec=27, tm_wday=1, tm_yday=318, tm_isdst=0),
#    'tags': [{'term': 'International Trade and World Market',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Labor and Jobs',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Supply Chain',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Trans-Pacific Partnership',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'United States International Relations',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'United States Economy',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'United States Politics and Government',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Brown, Sherrod',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Wyden, Ron',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Tai, Katherine (1974- )',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Far East, South and Southeast Asia and Pacific Areas',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Democratic Party',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Biden, Joseph R Jr',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Office of the United States Trade Representative',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None}],
#    'media_content': [{'height': '1800',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2023/11/15/multimedia/13JPdc-trade1-print-vwcg/13dc-trade-02-vwcg-mediumSquareAt3X.jpg',
#      'width': '1800'}],
#    'media_credit': [{'content': 'Kham/Reuters'}],
#    'credit': 'Kham/Reuters',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Economy.xml',
#      'value': 'A garment factory in Vietnam. Labor groups say some U.S. partners in the Indo-Pacific Economic Framework for Prosperity, like Vietnam, have low standards for protecting workers and unions.'}]}],
#  'feed': {'title': 'NYT > Business > Economy',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Economy.xml',
#    'value': 'NYT > Business > Economy'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://www.nytimes.com/section/business/economy'},
#    {'href': 'https://rss.nytimes.com/services/xml/rss/nyt/Economy.xml',
#     'rel': 'self',
#     'type': 'application/rss+xml'}],
#   'link': 'https://www.nytimes.com/section/business/economy',
#   'subtitle': '',
#   'subtitle_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Economy.xml',
#    'value': ''},
#   'language': 'en-us',
#   'rights': 'Copyright 2023 The New York Times Company',
#   'rights_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Economy.xml',
#    'value': 'Copyright 2023 The New York Times Company'},
#   'updated': 'Wed, 29 Nov 2023 19:16:31 +0000',
#   'updated_parsed': time.struct_time(tm_year=2023, tm_mon=11, tm_mday=29, tm_hour=19, tm_min=16, tm_sec=31, tm_wday=2, tm_yday=333, tm_isdst=0),
#   'published': 'Wed, 29 Nov 2023 17:49:53 +0000',
#   'published_parsed': time.struct_time(tm_year=2023, tm_mon=11, tm_mday=29, tm_hour=17, tm_min=49, tm_sec=53, tm_wday=2, tm_yday=333, tm_isdst=0),
#   'image': {'title': 'NYT > Business > Economy',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Economy.xml',
#     'value': 'NYT > Business > Economy'},
#    'href': 'https://static01.nyt.com/images/misc/NYT_logo_rss_250x40.png',
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/section/business/economy'}],
#    'link': 'https://www.nytimes.com/section/business/economy'}},
#  'headers': {'connection': 'close',
#   'content-length': '7815',
#   'access-control-allow-headers': 'Accept, Content-Type, X-Forwarded-For, X-Prototype-Version, X-Requested-With',
#   'access-control-allow-methods': 'GET, OPTIONS',
#   'access-control-allow-origin': '*',
#   'access-control-expose-headers': 'Content-Length, X-JSON',
#   'cache-control': 'public, max-age=300',
#   'content-type': 'application/xml',
#   'x-envoy-upstream-service-time': '45',
#   'server': 'envoy',
#   'x-envoy-decorator-operation': 'du-rss.publishing.nyti.nyt.net:443/*',
#   'content-encoding': 'gzip',
#   'accept-ranges': 'bytes',
#   'date': 'Wed, 29 Nov 2023 19:18:07 GMT',
#   'via': '1.1 varnish',
#   'age': '96',
#   'x-served-by': 'cache-vie6328-VIE',
#   'x-cache': 'HIT',
#   'x-cache-hits': '1',
#   'x-timer': 'S1701285488.975150,VS0,VE1',
#   'vary': 'Accept-Encoding',
#   'strict-transport-security': 'max-age=63072000; preload; includeSubdomains'},
#  'href': 'https://rss.nytimes.com/services/xml/rss/nyt/Economy.xml',
#  'status': 200,
#  'encoding': 'utf-8',
#  'version': 'rss20',
#  'namespaces': {'dc': 'http://purl.org/dc/elements/1.1/',
#   'media': 'http://search.yahoo.com/mrss/',
#   '': 'http://www.w3.org/2005/Atom',
#   'nyt': 'http://www.nytimes.com/namespaces/rss/2.0'}}

# %%
#print(data['Reuters']['rss'][0])
def print_scrape_status(count):
    print(f"Scraped {count} articles", end="\r")

def scrape(data,news_date):
    # Function that scrapes the content from the URLs in the source data
    try:
        articles_list = []
        for source, content in data.items():
            for url in content['rss']:
                d = fp.parse(url)
                for entry in d.entries:
                    article = {}
                    if hasattr(entry,'published'):
                        article_date = dateutil.parser.parse(getattr(entry,'published'))
                        if (article_date.strftime('%Y-%m-%d') >= str(news_date)):
                            try:
                                content = newspaper.Article(entry.link)
                                content.download()
                                content.parse()  
                                content.nlp()
                                try:
                                    article['source'] = source
                                    article['url'] = entry.link
                                    article['date'] = article_date.strftime('%Y-%m-%d')
                                    article['time'] = article_date.strftime('%H:%M:%S %Z') # hour, minute, timezone (converted)
                                    article['title'] = content.title
                                    article['title sentiment'] = analyze_sentiment(content.title)
                                    article['body'] = content.text
                                    article['summary'] = content.summary
                                    article['summary sentiment'] = analyze_sentiment(content.text)
                                    article['keywords'] = content.keywords
                                    article['image_url'] = content.top_image
                                    articles_list.append(article)
                                    print_scrape_status(len(articles_list))
                                except Exception as e:
                                    print(e)
                                    print('continuing...')
                            except Exception as e: 
                                print(e)
                                print('continuing...')
        return articles_list
    except:
        raise Exception(f'Error in "Scraper.scrape()"')

output = scrape(data,date(2023,11,29))
# Out:
# Scraped 17 articles

# %%
print(date.today())
print(date(2023,11,1))
# Out:
# 2023-11-29
# 2023-11-01

# %%
df = pd.DataFrame(output)
display(df[['source','time','title','title sentiment','summary','summary sentiment']].sort_values('summary sentiment'))
display(df[['body']])
# Out:
#             source          time  \
# 1   New York Times  14:33:05 UTC
# 9   New York Times  13:13:17 UTC
# 5   New York Times  18:59:25 UTC
# 6   New York Times  17:58:22 UTC
# 7   New York Times  15:54:39 UTC
# 4   New York Times  19:08:56 UTC
# 13  New York Times  10:01:54 UTC
# 8   New York Times  13:00:09 UTC
# 2   New York Times  18:54:46 UTC
# 0   New York Times  14:43:49 UTC
# 14  New York Times  12:05:29 UTC
# 12  New York Times  17:49:53 UTC
# 16  New York Times  17:49:53 UTC
# 10  New York Times  17:02:00 UTC
# 3   New York Times  19:14:53 UTC
# 11  New York Times  10:01:09 UTC
# 15  New York Times  17:38:08 UTC
#
#                                                                                title  \
# 1             Citi Is Sued Over Sex Abuse. Before 2022, It Would Have Been a Secret.
# 9                                          What to Expect at Today’s DealBook Summit
# 5                             London’s Black Cabs Can Soon Join Uber. But Will They?
# 6                      Don’t Be Afraid of the iPhone’s NameDrop Feature, Experts Say
# 7                  Here’s the Lineup for the 2023 DealBook Summit, and When to Watch
# 4            With Charlie Munger’s Death, Berkshire Loses a Custodian of Its Culture
# 13              Charles T. Munger, Much More Than Warren Buffett’s No. 2, Dies at 99
# 8                                        Jezebel to Be Resurrected by Paste Magazine
# 2                                   G.M. to Cut Spending on Cruise Self-Driving Unit
# 0                           In a Shaky Oil Market, OPEC Has Bitter Decisions to Make
# 14               Make Sure Your Google Accounts Are Active, or They Might Be Deleted
# 12              U.S. Debates How Much to Sever Electric Car Industry’s Ties to China
# 16              U.S. Debates How Much to Sever Electric Car Industry’s Ties to China
# 10                                       The Chicken Tycoons vs. the Antitrust Hawks
# 3   DealBook Summit Vice President Kamala Harris Interviewed at New York Times Forum
# 11                                   First Cruise: Preparations for a Smooth Sailing
# 15                               In the Stock Market, Don’t Buy and Sell. Just Hold.
#
#     title sentiment  \
# 1           -0.6369
# 9            0.0000
# 5            0.1531
# 6            0.0000
# 7            0.0000
# 4           -0.7351
# 13           0.0000
# 8            0.0000
# 2           -0.2732
# 0           -0.5719
# 14           0.6124
# 12           0.0000
# 16           0.0000
# 10           0.0000
# 3            0.0000
# 11           0.0000
# 15           0.0000
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                
# 9   The lineup for DealBook Summit 2023\n\nOn Wednesday, DealBook will be live and in person at our annual summit in New York.\n\nAndrew takes the stage around 9 a.m. Eastern, and the first interview kicks off soon after. The DealBook team and reporters from The Times will be reporting live from the conference.\n\nEven if you are not with us, you can follow along here beginning at 8:30 a.m. Eastern.\n\nHere are the speakers:\n\nVice President Kamala Harris\n\nTsai Ing-wen , the president of Taiw...
# 10  For Wu and others, the consumer-welfare standard is outdated. One of the overarching consequences of all that consolidation, they argue, is that companies have accrued too much power, and now they’re abusing it. The resulting dynamics contribute to a host of societal ills, like wage stagnation, stifled innovation, rising inequality and disproportionate political influence flowing to the ultrarich. Khan came to prominence in 2017 after she published a Yale Law Review article called “Amazon’s ...
# 11  You’ve picked a ship, booked an itinerary and chosen your cabin, but even with the hardest part done, figuring out the ship’s layout and how to get a spot on a popular outing can be daunting. Here’s how to prepare for a smooth first sailing.\n\nFamiliarize yourself with the ship, even before you board\n\nOcean cruise liners are big, and each ship is unique, so get familiar with deck layouts and features before you board. Most cruise companies have detailed plans and videos on their websites ...
# 12  The Biden administration has been trying to jump-start the domestic supply chain for electric vehicles so cleaner cars can be made in the United States. But the experience of one Texas company, whose plans to help make an all-American electric vehicle were upended by China, highlights the stakes involved as the administration finalizes rules governing the industry.\n\nHuntsman Corporation started construction two years ago on a $50 million plant in Texas to make ethylene carbonate, a chemica...
# 13  Charles T. Munger, who quit a well-established law career to be Warren E. Buffett’s partner and maxim-spouting alter-ego as they transformed a struggling New England textile company into the spectacularly successful investment firm Berkshire Hathaway, died on Tuesday in Santa Barbara, Calif. He was 99.\n\nHis death, at a hospital, was announced by Berkshire Hathaway. He had a home in Los Angeles.\n\nAlthough overshadowed by Mr. Buffett, who relished the spotlight, Mr. Munger, a billionaire i...
# 14  The company said when it announced the policy that it was for security reasons: Accounts that have not been used for a long time are more likely to be compromised. It also said that idle accounts were 10 times less likely to have two-factor verification, which checks a user’s identity.\n\nThe policy applies only to personal accounts, not those managed by a business or school.\n\nGoogle said certain accounts would be exempt from deletion, even if they were inactive for two years, including th...
# 15  Selling all of your stock just before the market falls, and buying shares just before the market rises, is a brilliant strategy.\n\nIf you could really do it, you would have bragging rights among your friends. And if you could repeat the feat over and over again, you would be fabulously rich — a true stock market wizard.\n\nBut the ability to trade like that is rare, if it exists at all. Without question, it’s so hard that the vast majority of professional traders can’t do it, as countless s...
# 16  The Biden administration has been trying to jump-start the domestic supply chain for electric vehicles so cleaner cars can be made in the United States. But the experience of one Texas company, whose plans to help make an all-American electric vehicle were upended by China, highlights the stakes involved as the administration finalizes rules governing the industry.\n\nHuntsman Corporation started construction two years ago on a $50 million plant in Texas to make ethylene carbonate, a chemica...

# %%
display(df[['summary sentiment','summary']].sort_values('summary sentiment'))
# Out:
#     summary sentiment  \
# 1             -0.9674
# 9             -0.9357
# 5             -0.7959
# 6             -0.6857
# 7             -0.5423
# 4             -0.0772
# 13             0.1779
# 8              0.3716
# 2              0.6712
# 0              0.7883
# 14             0.8750
# 12             0.9495
# 16             0.9495
# 10             0.9515
# 3              0.9523
# 11             0.9765
# 15             0.9822
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                